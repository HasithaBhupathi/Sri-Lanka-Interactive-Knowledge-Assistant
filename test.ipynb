# %% [markdown]
# # **Retrieval-Augmented Generation (RAG) Pipeline**

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# #### **Load and Extract the Data**

# %%
from langchain.document_loaders import PyPDFLoader

def read_doc(pdf_name):
    
    ### load the pdf
    data = PyPDFLoader(pdf_name)

    extract_data = data.load()
    ### extract all pages as documents 
    
    return extract_data

# %%
documents = read_doc("INTRODUCTION.pdf")
documents
# Out:
# [Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 0, 'page_label': '1'}, page_content='1\nSRI LANKAN FAMILIARIZATION COURSE \nIntroduction To  \nSRI LANKA \n \nGEOGRAPHY  \n \nSri Lanka is a 25,000 sq mi (65, 610 sq. km) tropical island paradise and a major tourist destination.  \ne. It is just off the southeastern coast of India between five and 10 degrees north of the equator. It is \nstrategically located near Indian Ocean sea lanes. It is slightly larger than West Virginia.  It has a \nbeautiful coast line of 1,340 kilometers which attracts a lot of tourists all year around. Sinharaja, \nwhich is one of world’s protected tropical rain forests, is located in Sri Lanka.  \n \nThe administrative capital, Sri Jayawardenpura-Kotte, is located near the largest city, Colombo, at \nabout 6 degrees north latitude and 79 degrees east longitude.  \n \n \n \nSri Lanka Map Sri Lanka lies off the southeast coast of India.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='2\n         Flag of Sri Lanka \n \nThe flag of Sri Lanka shows a lion holding a sword which signifies that the Sinhalese who are the \nmajority belongs to the lion race which is a mythological belief.  The bo leaves at the four corners \nsignify the Buddhist religion which is the religion of the majority of the Sinhalese.  The green stripe \nto the left signify the Muslim minority and the orange stripe signifies the Tamil minority. \nDescription \n \nCLIMATE  \nThe climate of Sri Lanka is tropical with rains from the northeast monsoon from December to \nMarch and southwest monsoon from June to October. The coastal areas are warm and humid but the \ncentral hills are cooler and less humid. December and January are usually the coolest months and \ntherefore considered the best time of year to visit. Some western slopes receive up to 2500 mm (100 \ninches) of rain per month (not year!), but the leeward slopes in the east and northeast receive little \nrain. \nMay is the hottest month, with the heavy monsoon rains soon arriving from the west to cool things \ndown. Nuwara Eliya in the Central Highlands has the lowest mean temperature at 16°C. Contrast \nthat with Trincomalee on the northeast coast, which has a mean temperature of 32° C, sometimes \nrising to 38 °C. The average yearly temperature for Sri Lanka as a whole is between 28 to 30 °C. \nDue to its proximity to the sea, day and night temperatures may vary by only 4 to 7° C.  \n \nTERRAIN \nSri Lanka is shaped like a pear. Sri Lanka’s terrain is low, flat to rolling plains near the coast, and \nmountainous at the center.  The mountains are only in the south-central section of the island, the \nhighest, Pidurutalagala (Mt Pedro), is 2,524 meters, or 8,281 feet. The many rivers (called gangas \nafter India’s Ganges River) are well-fed by the rains. The largest rivers are located in the southwest.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='3\n \nPOPULATION  \nThe population of Sri Lanka in the 2001 census was 18,732,255 giving it a population density of \n818/square mile. The Human Development index in 2006 was 93rd in the world at .7555 It was \nestimated that 15% of the population lived in urban areas in 2001 The economic capital, Colombo, \nis the largest city with a metropolitan population of over 600,000. Other urban centers include: \nDehiwala 209,787 (2001)  \nJaffna 145,600 (1997 estimate)  \nSri Jayawardenepura 115,826 (2001)  \nKandy 110,049 (2001)  \nGalle 90,934 (2001)  \n \nDue to the civil war, Sri Lanka has a large number of refugees and internally displaced persons. \nThey include both Tamils and non-Tamils  and number 500,000-600,000 (2006). After the \nhostilities between the government and armed Tamil separatists began in the mid-1980s, several \nhundred thousand Tamil civilians have fled the island and more than 200,000 Tamils have sought \nrefuge in the West (July 2006 est.) \n \nThe largest ethnic groups in Sri Lanka are the Sinhalese at 74%, the Tamils at 18%, and Sri Lankan \nMoors (descendents of Arab traders) at 7%. Tamils can be further broken down into Indian Tamils \nand Sri Lankan Tamils.  2001 census data indicates the following breakdown of religious affiliation: \nBuddhist 69.1%, Muslim 7.6%, Hindu 7.1%, Christian 6.2%, unspecified 10%. Sri Lanka’s \nLanguages include Sinhala (official and national language) 74%, Tamil (national language) 18%, \nother 8%. English is commonly used in government and is spoken competently by about 10% of the \npopulation. The level of literacy is 93%. \n \nGOVERNMENT   \nThe Sri Lankan government is a democratic socialst republic, with a Western-style parliamentary \ndemocracy, has a presidential system of government.  The voting age in Sri Lanka is 18 years. \nPresident is the head of the state and wields executive power.  He/she is also the commander in \nchief of the armed forces. He/she is elected by popular vote and holds power for six years. He/she \ncan be re-elected for a second term which is the maximum period for the president.  The legislative \npower is with the parliament which is also elected for a period of six years but the president has the \npower to dissolve it at any time. The unicameral legislative branch has 225 seats.  Sri Lanka’s \njudicial branch has a Supreme Court and a Court of Appeals. Judges for both courts are appointed \nby the president. Sri Lanka also has an independent judiciary which stands as a buffer between the \nPresident and the parliament.  The President appoints the Prime Minister from the largest party \nrepresented in the parliament and also the cabinet.  The President is the head of the cabinet as well.  \nThus, the President of Sri Lanka is very powerful. The current president is Mahinda Rajapakse and \nthe prime mintister is Ratnasiri Wickremanyake, elected in April, 2004.   \n \nThere are several political parties that represent all shades of opinion from capitalism, socialism, \nnationalism, and to Marxism. The main parties are the Sri Lanka Freedom Party (SLFP) which is a \nsocial democratic party and the United National Party (UNP) which is a capitalist party.  The \nMarxists have three main political parties, namely, the Peoples’ Liberation Front, the Equal Society \nParty and the Communist Party of which the People’s Liberation Front (PLF) has now become the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='4\nstrongest. While the PLF is Marxist in orientation, it is also a radical nationalist party mostly of \nSinhalese.   \n \nThere are other nationalist parties and pressure groups such as the Jathika Hela Urumaya which is a \nSinhalese-Buddhist nationalist party, Buddhist clergy, radical chauvinist Sinhalese groups such as \nthe National Movement Against Terrorism, the Tamil Nationalist Alliance (TNA) that is supported \nby Liberation Tigers of Tamil Elaam (LTTE) which is a terrorist organization that controls parts of \nNorthern and Eastern and fighting for a separate state lead by Velupillai PRABHAKARAN, Ceylon \nWorkers Congress (CWC) which represents the Tamils of recent Indian origin who live central Sri \nLanka, Tamil United Liberation Front (TULF) and the Elam Peoples Democratic Party (EPDP). The \nLTTE doesn’t tolerate political freedom and therefore Tamil democratic parties such as the Tamil \nUnited Liberation Front (TULF), Elam Peoples Democratic Party (EPDP) and others are not \nallowed to function freely in the areas under their control. \n \nThe Tamil minority that forms the majority in the Northern and Eastern provinces is clamoring for \nautonomy and the LTTE has gone a step further and wants to create a separate state for the Tamils \nthrough an armed uprising.  The Sri Lankan state has been fighting the LTTE rebel forces for more \nthan two decades.  The on going armed conflict between the two sides is the main political problem \nthat Sri Lanka faces at present.  Because of the civil war there are reports of human rights violations \nand racial tension between the majority Sinhalese community and the minority Tamil community.  \nOver time, most Tamils have come to the realization of the futility of armed conflict and want to \nreach a peaceful settlement with the government which has agreed to devolve substantial power to \nthe Tamil majority areas.  However, the refusal of the LTTE to agree to government proposals has \nresulted in a political impasse and continued violence.   \n \nDiplomatic representation in the US\n: \nChief of mission: Ambassador Bernard GOONETILLEKE  \nChancery: 2148 Wyoming Avenue NW, Washington, DC 20008  \ntelephone: [1] (202) 483-4025 (through 4028)  \nFAX: [1] (202) 232-7181  \nConsulate(s) general: Los Angeles  \nConsulate(s): New York \n \nDiplomatic representation from the US:\n \nChief of mission: Ambassador Robert O. BLAKE, Jr.  \nEmbassy: 210 Galle Road, Colombo 3  \nMailing address: P. O. Box 106, Colombo  \nTelephone: [94] (11) 249-8500  \nFAX: [94] (11) 243-7345'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='5\nHISTORY \n \nA Thumbnail Description of Sri Lanka’s History \nThe Sinhalese arrived in Sri Lanka late in the 6th century B.C.E., probably from northern India. \nBuddhism was introduced beginning in about the mid-third century B.C.E. (see religion, below), \nand a great civilization developed at the cities of Anuradhapura (kingdom from circa 200 B.C.E. to \ncirca C.E. 1000) and Polonnaruwa (from about 1070 to 1200). In the 14th century, a south Indian \ndynasty seized power in the north and established a Tamil kingdom. Occupied by the Portuguese in \nthe 16th century and by the Dutch in the 17th century, the island was ceded to the British in 1796, \nbecame a crown colony in 1802, and was united under British rule by 1815. As Ceylon, it became \nindependent in 1948; its name was changed to Sri Lanka in 1972.  \n \nTensions between the Sinhalese majority and Tamil separatists erupted into war in 1983. Tens of \nthousands have died in the ethnic conflict that continues to fester. After two decades of fighting, the \ngovernment and Liberation Tigers of Tamil Eelam (LTTE) formalized a cease-fire in February 2002, \nwith Norway brokering peace negotiations. Violence between the LTTE and government forces \nintensified in 2006, but neither side has formally withdrawn from the cease-fire. The tsunami of \nDecember, 2005 devastated more than half of the coastline of Sri Lanka, with more than 30,000 \npeople reported dead or missing.   \n \n \n  \nThis gentleman catches a ride in a U.S. military \ntruck a month after the 2004 Tsunami. The US \nwas one of many countries to provide assistance \nafter the disaster. Photo by JPS 2005 \nThe ancient palace fort of Sigiriya is a popular site for domestic \nand foreign tourists alike. \n 2005 by Jeffrey P. Smith'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 5, 'page_label': '6'}, page_content='6\n30,000 Sri Lankans were lost in the 2004 tsunami. Many \nmore lost their homes. By Jeffrey P. Smith (JPS) \n \nA fishing boat cast upon the shore by the tsunami.  \n      By JPS  \n \n \n \n \n \nThree-wheel taxi in front of devastated tourist shop. By \nJPS \nVolunteers pack sugar for tsunami victims. By JPS'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 6, 'page_label': '7'}, page_content='7\nECONOMY  \nThe Sri Lankan economy is still considered volatile.  Sri Lanka’s 2005 GDP is about $86.72 billion \n(61st) and per capita is about $4300 (111th). Their currency is the Sri Lankan Rupee (Rs.).   \n \n \n \nA coconut shell and a stick are used to tap a rubber tree. Photo by \nJPS  \nFront and back of a two rupee coin. \n \n \nIt is primarily an agricultural country with rice growing as the major occupation.  Sri Lanka is also \none of world’s leading producers of tea which grows in the hill country.  Aside from tea, rubber and \ncoconut are the other two main commercial export crops.  It is also famous for valuable gemstones \nsuch as sapphires, rubies, and cat’s eyes. Also, Sri Lankan mines are particularly known for gems \nsuch as emeralds.  Recently, garment manufacturing. \nNatural resources include: limestone, graphite, mineral sands, gems, phosphates, clay, and \nhydropower. The majority of energy is produced with imported oil. The main domestic energy \nsource is hydroelectric, which provides nearly half of total electric output. Total electricity \nproduction in 2004 was 7.714 billion kWh. Blackouts due to shortages are common. \nSri Lanka has economic growth has been stunted since the civil war began in the early 1980’s. \nDespite this Sri Lanka’s life expectancy at birth is 73 years and general good physical health has \nremained high, due in part to strong public health education.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 7, 'page_label': '8'}, page_content="8\n \nIn 1977, Colombo discontinued economic policies that involved a high degree of government \nintervention and its import substitution trade policy for more market-oriented policies, export-\noriented trade, and encouragement of foreign investment. Recent changes in government have \nbrought some policy changes, however. Currently, the ruling Sri Lanka Freedom Party has an \neconomic approach involving more government intervention which seeks to reduce poverty by \nsteering investment to disadvantaged areas, developing small and medium enterprises, promoting \nagriculture, and expanding the already large civil service. The government has halted most \nprivatizations. Although suffering a brutal civil war that began in 1983, Sri Lanka saw GDP growth \naverage 4.5% in the last ten years, with a brief interruption during the global downturn in 2001.  \n \nIn late December 2004, a major tsunami took about 31,000 lives, left more than 6,300 missing and \n443,000 displaced, and destroyed an estimated $1.5 billion worth of property. Growth, partly \nspurred by reconstruction, has reached 5% in 2005 and more than 6% in 2006. Sri Lanka's most \ndynamic sectors now are food processing, textiles and apparel, food and beverages, port \nconstruction, telecommunications, insurance and banking. In 2005, plantation crops made up only \nabout 15% of exports (compared with more than 90% in 1970), while textiles and garments \naccounted for more than 60%. Sri Lanka has no domestic Oil production, while consuming 80,000 \nbbl/day (2004 est.).\n About 800,000 Sri Lankans work abroad, 90% in the Middle East. They send \nhome about $1 billion a year. The struggle by the Tamil Tigers of the north and east for a largely \nindependent homeland continues to burden the economy. \n \nIn 2006, the annual value of Sri Lanka's imports, $9.655 billion f.o.b., is greater than that of its \nexports, $7.076 billion f.o.b. in 2006. External debt totals $12.23 billion. Sri Lanka received $577 \nmillion in economic aid in 1998. The main import trading partners are: India 20.7%, Singapore \n8.3%, Hong Kong 7.3%, China 7.1%, Iran 5.9%, Malaysia 4.4%, and Japan 4.3%. (2005). Imports \ninclude: textile fabrics, mineral products, petroleum, foodstuffs, machinery and transportation \nequipment. Exports partners include: US 31.1%, UK 12.2%, India 8.9%, and Germany 4.3% \n(2005). Exports include: textiles and apparel, tea and spices; diamonds, emeralds, rubies; coconut \nproducts, rubber manufactures, and fish. \n \n \n \nFishing boats such as these are used extensively on the Sri Lankan coast."),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 8, 'page_label': '9'}, page_content='9\n \n \nA community of fisherman makes its first catch a month after the devastating 2004 tsunami.  \n \nA crowd gathers around the day’s catch of fish. \n \nMajor sectors of Sri Lanka’s economy include: agriculture: 17.3%, industry: 27.3%, services: \n55.3% (2006 est.). The labor force of 8.2 million includes: agriculture: 38%, industry: 17%, \nservices: 45% (1998 est.). Other important economic data include: unemployment rate: 7.6% (2006'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 9, 'page_label': '10'}, page_content='10\nest.); population below poverty line: 22% (1997 est.); consumer inflation rate: 12.1% (2006 est.) \nThe national budget in 2006 included revenue of $4.762 billion and expenditures of $7.095 billion. \nPrimary agricultural products include: rice, sugarcane, grains, pulses, oilseed, spices, tea, rubber, \ncoconuts; milk, eggs, hides, beef; and fish. Major industries include: processing of rubber, tea, \ncoconuts, tobacco and other agricultural commodities; telecommunications, insurance, banking; \nclothing, textiles; cement, and petroleum refining. A sampling of exchange rates provides the \nfollowing data: Sri Lankan rupees (currency code LKR) per US dollar - 102.987 (2006), 95.662 \n(2002). \n \nEDUCATION \nEven though Sri Lanka is considered a third world country, the education level is quite high. It \nenjoys one of the highest literacy rates in Asia. According to 2000-2004 UN estimates, 91% of Sri \nLanka’s adult population is considered literate. It’s mainly due to the fact that education in Sri \nLanka is free up to the university level. \n \nThe system of education in Sri Lanka was originally derived from the British system. However, it \nhas undergone important changes since the country became independent in 1948. The education \nstructure is divided into five parts; namely, primary (grades 1-5), junior secondary (grades 6-9), \nsenior secondary (grades 10-11), collegiate (grades 11-12), and tertiary. Education is compulsory \nfor all up to grade 9. After completing senior secondary education, students sit for the General \nCertificate of Education (GCE) Ordinary Level Examination (normally called O level). After \npassing the examination the student has the option of leaving the high school to join a vocational \nschool or go on to collegiate education that lasts for two years at the end sit for the GCE Advanced \nLevel Examination (normally called A level).  \n \nIf the student obtain high marks, (s)he will get an opportunity to be admitted to a university. \nUniversity education is not provided by quarters or semesters, but yearly. Since entrance to Sri \nLanka’s universities is highly competitive due to lack of space and facilities, only those who get \nvery high marks gets admitted. Others have several options: go abroad and join foreign universities \nand colleges; continue their education at several private educational institutes; enter teacher training \ncolleges; join continuing educational programs of traditional universities or the Open University \nand sit for degree examinations as external candidates; enter the job market; help the family \nbusiness, etc.  \n \nIn schools, the medium of education is Sinhala or Tamil which is called the first language.  English \nis the second language for all students.  The first language and mathematics are compulsory.  In the \nuniversities, medicine and engineering are taught only in English while other subjects can be \nstudied in Sinhala, Tamil, or English.  The most popular subject areas of study in Sri Lanka are \nsocial and general sciences, languages, engineering, medicine, law, and business related subjects.  \nAvailability of vocational schools is limited.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 10, 'page_label': '11'}, page_content='11\n \n \nThese six-year-old girls are in class at a Buddhist monastary in southern Sri Lanka. Photo by JPS  \n \n Most of the schools in Sri Lanka require st udents to wear uniforms. The female students \nwear a white dress with the school tie and male students wear white shirts with mostly blue pants. \nDifferent schools have different ties to differentiate their school. Usually schools have school bands \nand sports teams as well.  \n \n \nCOMMUNICATION \nSri Lanka had over 1.5 million telephone main lines and 4.28 million cell phones in 2006. These \nsystems provide good telephone services in most parts of the country.  The international country \ncode for Sri Lanka is 94. The two Intelsat satellite earth stations seem to provide clear if sometimes \nspotty service to places such as North America. Internet users in 2005 were estimated to be 280,000, \nThe internet country code is .lk. TV stations number 14 and radio stations 34. \n \nSri Lanka’s news media is comprised of newspapers and television.  Sri Lankans are eager readers \nand listeners to political news.  Because of the high literacy rate in the country, many Sri Lankans \nread the newspapers.  The political news is freely circulated by television and newspapers.  Even \nthough the Sri Lankan media is generally free, because of the on-going civil war, news related to \nnational security is somewhat controlled by the government.  There are six television stations which \nbroadcasts in Sinhala, Tamil, and English.  Except for one, all other TV stations are privately owned.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 11, 'page_label': '12'}, page_content='12\nRupavahini is the government owned TV station. There are several newspapers in Sri Lanka which \npublished in Sinhala, Tamil, and English.  While The Lake House, which is one of the leading \nnewspaper companies is owned by the government, the other newspaper companies are privately \nowned. Two leading newspaper companies which are privately owned are the Vijaya Newspapers \nLtd., and the Upali Group.  There are newspapers published by the different political parties as well. \n \nA giant Buddha sits next to a microwave tower on top of a \nmonolith. Photo by JPS \n \nTRANSPORTATION \nThe main international airport is near Colombo, in Katunayayaka  and despite heavy security, came \nunder attack by the Tamil rebels several years ago. Tourists are usually travel by taxis or rented \nvehicles. \n \nThe most common mode of transport of citizens of Sri Lanka is public buses and trains.  According \nto recent statistics published by the World Bank, only 4.3% of the population own private vehicles.  \nOut of this 1% are cars. The driver sits on the right. There are many motorcycle owners in Sri Lanka.  \nThe public transportation in Sri Lanka is extensive.  The country is served by an extensive network \nof roads.  Sri Lanka has almost 1,500 km of railways, almost all broad gauge. Sri Lanka has 97,287 \nkm of roadways of which 80% are paved. Their often narrow, winding ways contribute to a high \naccident rate. In general, anyone can have access to transportation within 20 minutes.   \n \nTransportation of goods is mostly done by lorries (trucks) and to some extent by train. Sri Lanka \nhas 16 airports, 14 paved. Seaports with terminals include Colombo and Galle. The trishaws, mostly \nwith the two stroke engine have become numerous and popular during recent years.  Bullock carts, \ndrawn by oxen, have largely gone out of use, but are seen occasionally. \n \nWhen traveling by train in Sri Lanka, the tickets have to be bought at the ticket counters of the \nrailway station.  In express and long distance trains there are three classes. First class is the most \ncomfortable, as well as most expensive. Third class is the least expensive and least comfortable,  \nand is often overcrowded. There are no classes in local trains. If you travel by bus, tickets are sold \ninside the bus by the conductor. There are regular buses as well as air-conditioned luxury buses that \nrun long distances.  Some of them are express buses. Also, there are no classes in buses and drivers \ndo not issue tickets.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 12, 'page_label': '13'}, page_content='13\n \n  \nOther modes of transport include: vans \n(usually rented); \nTaxis (three and four wheel); and bicycles. Photos by JPS \n \n \nMILITARY \n \n \nSri Lanka Navy Soldier wearing in his uniform. \n \nThe three military branches, army, navy and air force accept volunteers at age 18 (there is no \nconscription). 2005 military expenditures are estimated at $606 million, or about 2.6% of GDP. \n \n \nHEALTH \nSri Lanka is one of the few developing countries in the world where there is a well organized state \nsponsored healthcare system.  Healthcare is generally free for all. Consequently, there is no need fro \ncitizens to buy health insurance even though health insurance is available for people to buy if they \nwant to. Health insurance premiums are high and if one has health insurance, one can get good \nquality care from private hospitals in the urban areas.  The state hospitals lack the quality and \nfacilities that are found in the United States, particularly in the area of aftercare.   \nThe doctors are well-trained and qualified (many specialists are trained abroad in developed \ncountries) but many state hospitals lack modern facilities.  However, if one wants to get high quality \ncare, there are private hospitals and clinics in the urban areas that are available to provide them.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 13, 'page_label': '14'}, page_content='14\nThe best private hospitals are located in the capital city of Colombo.  Doctors in state hospitals are \nallowed to do private practice after working hours, which is called “channeling.”   In the rural areas, \nmost of the hospitals and clinics are run by the state.   \nIn Sri Lanka it is not necessary to have insurance to visit emergency rooms unless it is a private \nhospital.  Unlike in the United States, people do not go the emergency room often.  Mostly, accident \nvictims or people with sudden illnesses are taken to the emergency room.  Unlike in the United \nStates, except in big cities like Colombo, there are no ambulance services that people can call in an \nemergency. They have to arrange their own private transportation.  \nEven though English is widely spoken and understood, it is important to know Sinhala or Tamil to \ncommunicate with the local people, particularly in an emergency or delivering medical assistance to \npeople.  However, once the patient is taken to the hospital, the communication can be done in \nEnglish because all doctors know English.  However, English knowledge among the nursing staff is \nlimited and knowledge of local languages would be very helpful in dealing with them.  \n \nRELIGION \n \nArts and sculptures outside of the temple in Ruwanveliseeya in \nAnuradhapura. Photo by JPS \nA  stone Buddhist  statue in the ancient city of \nAnuradhapura. Photo by JPS'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 14, 'page_label': '15'}, page_content='15\nThe predominant religion in Sri Lanka is Thervadan Buddhism (sometimes mistakenly refered to as \nHinayana (lesser vehicle) Buddhism). Sri Lanka’s Theravada Buddhism is quite similar to that \nwhich is found in Cambodia, Myanmar (Burma) and Thailand. Theravada, or school of the elders, is \nconsidered to most closely follow the actual teachings of the Buddha. The government strongly \nsupports Buddhism, and Buddhism has a strong influeence on Sinhalese culture.  The roots of Sri \nLankan Buddhism go back to the third century B.C.E. when India’s Emporeror Ashok sent his son \nMahinda, an accomplished Buddhist monk, to Sri Lanka to help spread the dhamma (sanskit: \ndharma), or teachings of the Buddha. He famously encountered King Devanapiatissa who was \nhunting in the forest at the time. Devanapiatissa was impressed with Venerable Mahinda’s \ndemeaner and soon commited his life to following the dhamma. Sri Lanka was early in committing \nthe Buddhist teachings to writing, an important step in helping to preserve them for future \ngenerartions. \n \nThere are many places to read about the historical Buddha who lived in what is now known as north \nIndia. Theravada Buddhism recognizes him as an extraordinary mortal human being who developed \nhimself morally and mentally to such a degree that he experienced on a very deep level these three \npowerful truths of existence: annica, annata, and dhukka. These are usually translated as \nimpermance, non-self and suffering.The term Buddha referes to someone who is “awake”, awake to \nthe true nature of reality. This “awakening” is possible for any human being to experience if their \nmorality and mental abilities are properly developed.  \n \n       \nLife-size elephant statues decorating the base of a giant Stupa.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 15, 'page_label': '16'}, page_content='16\n \nA novice monk shares a blossom. Photo by JPS \n \nThe vast majority of Tamil’s are Hindu. Buddhism and Hinduism have coexisted for thousands of \nyears, leading to some joining of religious elements. This has resulted in Buddhists and Hindus \nsharing a common devotion to many of the same sacred sites and entities. Sri Lanka’s Buddhist \ntemples, for example, even have sections for Hindu deities. \n \n \nElder sisters pay homage to the Buddha. Photo \nby JPS \nStupas are shrines to the Buddha. This one is at the \nancient city of Anuradhapura. Photo by JPS'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 16, 'page_label': '17'}, page_content='17\n \nETHNIC GROUPS \nEthnic Sinhalese make up 74% of the population.  Tamils make up 18%.   There are smaller \ncommunities of Moors (8%, descended from Arab traders). The Veddahs, Sri Lanka’s indigenous \ntribal people, make up a very small portion of the population. Refugees and internally displaced \npersons number between 500,000-600,000, including both Tamils and non-Tamils displaced due to \nthe long-term civil conflict. \n \n \nCULTURE \nAs a nation with long history of civilization, Sri Lanka is famous for art, crafts, music, literature, \ndance, architecture.  Beyond that Sri Lanka is a family-oriented culture. \n \n \nThe Perahera processon is Sri Lanka’s biggest celebration. These girls are \npreparing for their villages version. by VWS 1995'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 17, 'page_label': '18'}, page_content='18\nSinahlese Buddhist Grandmothers go to Temple by VWS 2005 Kandian Drummer by JPS 2005 \n   \nGENERALCUSTOMS, ETIQUETTE AND HOSPITALITY \n \n \nA young woman in Sri Lanka makes a formal welcoming \nby saying ‘Aryuboovan’. (Photos of Sri Lanka: \nCourtesy—Google Images)'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 18, 'page_label': '19'}, page_content='19\n \nA family mourns a loved one. Funera ls are often performed in the home. by JPS 1998 \n \nExterior of a typical Sri Lankan home surrounded by \nflowers, and fruit and, coconut trees. by JPS \nBathroom facilities found in Sri Lanka. by VWS. \n \n \nBuddhist monks often are invited to visit homes. They may chant scriptures and share teachings of the Buddha, \nand the householder will offer them food and beverages. The monk is holding a glass bottle with holy water.  by \nVWS'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 19, 'page_label': '20'}, page_content='20\nSri Lankans are very hospitable; guests are their central attention and are highly treated in their \nhomes.  For social gatherings Sri Lankan homes will prepare well-seasoned, spicy food, the hosts \nwill be busy filling guests’ plates and glasses whenever those are empty or low.  After a helping or \ntwo it is acceptable to refuse politely or, more simply, just leave a little uneaten food on the plate.  It \nis considered rare and unusual for one to go inside and Sri Lankan household and not be offered tea \nand food.  \nFAMILY \n \nSri Lankans can be found living in both nuclear and extended families.  \n \nWedding \n \n  \nSri Lankan Kandian bride  \n(Photos of Sri Lanka: Courtesy—Google Images) \nOn the day after her wedding the bride wears red. \n \nFOODS \nSri Lanka’s tropical climate helps much of the island to be like a garden. The main meal consists of \ncooked rice and curries. Meat is expensive in Sri Lanka and mostly fresh fish, dry fish, curd, and \ndhal are used as sources of protein. Also, white bread called pan is eaten mostly for breakfast and \nsometimes during dinner. All manner of fruits and spices are grown with great ease mostly in home \ngardens. The fruits that are commonly grown in the garden include a wide variety of bananas,  \npapaya, oranges, jack fruit, guava, and all kinds of fruits that are not found in the United States. \nBesides fruit it is not uncommon to see tea, coffee, cinnamon and coconut trees growing in people’s \nhome gardens.  \nSinhalese cuisine is, to the European or American palate, quite similar to the more familiar East \nIndian cuisine. Tamil cuisine is obviously derived from the south Indian Tamil food and mostly \nhotter. Sinhalese food will contain vegetables and non-vegetarian foods since strict vegetarianism is \nnot prescribed by the Buddhist precepts. Spicy hot food can be either extreme or moderate.  The Sri \nLankan cuisine uses herbs and spices that include cinnamon, cardamom, clove, cumin, nutmeg, \ngarlic, thyme, curry leaves and curry powder etc. Below are photos of common ethnic dishes that \nSri Lankans prepare.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 20, 'page_label': '21'}, page_content='21\nVegetable and fruit stands are very common along the urban \nstreets and rual roadsides.  \nFruit for sale. \n \n \n \n \n  \nCleaning jack fruit nuts for dinner. Vegetables ar e often cut by holding the knife with the foot.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 21, 'page_label': '22'}, page_content='22\n \nCooking hearth fueled by fire wood blown with a blower. Almost all pots used by common people are made with clay. \n  \n \n  \nOld fashion cooking with clay pots Fuel consists of coconut shells. She \nis preparing a curry with coconut milk.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 22, 'page_label': '23'}, page_content='23\n  \n  \n \nStoring of covered pots with food on the extinguished \nhearth. \nGrinding coconut “scraps”. Photo by JPS \n \n \n \nMortar and pestle for food preparation. Grinding coconut “scraps”. Photo by JPS'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 23, 'page_label': '24'}, page_content='24\n \n  \nYoung coconut is a cool  safe and refreshing drink.   \n \nJust insert a straw into the sliced young coconut and your drink is ready.  These brooms are used to clean after \nthe meal. Photo by JPS 1998'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 24, 'page_label': '25'}, page_content='25\nARTS \n Sri Lanka is a country of cu ltures that includes almost everything: architecture, music \n(folk and contemporary), literature, art (pottery, wood and stone), jewelry, etc.  \n \nARCHITECHER \n \n \nSri Lankan Buddhists visit one of the most revered sites in Sri \nLanka, the temple where aTtooth of the Buddha is kept. \nArt in the Temple of the Buddha’s Tooth in \nKandy. \n \n \n \n  \nDetail of statue in the Temple of the Tooth in Kandy. Tusks are used in this display in Kandy.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 25, 'page_label': '26'}, page_content='26\n \nStatue in Temple of the Tooth. Photo by JPS Hemamali  brinsg the Buddha’s tooth to Sri Lanka hidden \nin her hair with her husband Danthakumaru.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 26, 'page_label': '27'}, page_content='27\n \n  \nLate 20th Century Buddha. Photo by JPS Ceiling of village Buddhist temple. Photo by JPS \n \nLITERATURE \nThere are a number of good-to-excellent books about Sri Lanka.  A few of these are described \nbelow. Booker Prize-winning author Michael Ondaatje (The English Patient) has written two \nexcellent books about his homeland, Running in the Family, as well as Anul’s Ghost. His brother \nChristopher Ondaatje wrote The Man-Eater of Punanai. The Architecture of an Island: the Living \nHeritage of Sri Lanka is a great work and a beautiful book by Ronald Lewcock, Barbara Sansoni \nand Laki Senanayake (difficult to find outside of Sri Lanka).  \nAn excellent source of Buddhist literature is the Buddhist Publication Society in Kandy, Sri Lanka  \nhttp://www.bps.lk/ P.O. Box 61, No. 54, Sangharaja Mawatha, Kandy, Sri Lanka. Tel: +94 81-223-\n7283 & 81-223-8901, Fax: +94 81-222-3679. \nThe BPS distubuter in the US is Pariyatti, http://www.pariyatti.com/.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='28\nTOURISM \nThe climate, environment, history and warmth of the people help to make Sri Lanka an inviting \nplace to visit. We have prepared the following general advice for travelers to Sri Lanka. Because of \nthe civil war, it is recommended to review sources that are consistently updated on Sri Lanka’s \nconditions.   \nForeign tourists have not been targeted by violence in Sri Lanka, but could become victims to it \ninadvertently. Until late 2006 terrorist and war activities seldom reached outside of the northern and \neastern parts of the island, with the occasional attack in Colombo. Violent activity has now \nincreased in tourist areas in the south and central regions of the island. A bright spot is that \nforeigners willing to travel in Sri Lanka might appreciate the reduction in other visitors brought \nabout by the war and the tsunami.  \n \nLocal customs \nStandards of dress and behavior are usually more conservative than in western countries. For \ninstance, when visiting places such as temples you should cover your legs. Take care when \ndoing activities such as photographing statues of the Buddha. You should receive permission \nand ask for guidelines when doing so (e.g. you may be asked to not have people in the photo \nwith the statue). \nHealth Issues \nMany food-borne, water-borne and other infectious diseases such as typhoid, hepatitis and \nrabies can be prevented by vaccinations. Others, such as malaria, dengue fever, chikungunya \nfever, Japanese encephalitis and filariasis, can be prevented by avoiding mosquito bites. There \nis malaria risk in all areas, except for the districts of Colombo, Galle, Kalutara, and Nuwara \nEliya.  \nThe Ministry of Healthcare and Nutrition in Sri Lanka recently confirmed cases of \nchikungunya fever in patients from several districts; the most affected districts are Batticaloa, \nColombo, Jaffna, Kalmunai, Mannar, Puttalam, and Trincomalee. Surveillance activities for \nchikungunya fever cases are continuing in sentinel hospitals in Sri Lanka. There are no \npreventive medications or FDA-approved vaccines for chikungunya fever, but travelers can \ntake steps to reduce their risk of being bitten by infected mosquitoes. \nThere have been no recent outbreaks in polio and avian flu. \n \nLocal Laws \nTake care to observe all local laws. There are penalties for drug trafficking and homosexual \nacts. It is prohibited to take photos and video tape in high security zones (HSZs) such as some \ngovernment buildings and military establishments.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 28, 'page_label': '29'}, page_content='29\nMonkeys are very common the Ancient city Anurahdapura where tourisst and pilgrims visits. \n \n  \nOffering of flowers to the Buddha by pilgrims are visited by a \ncommon monkey in the area and a boy from USA. Photo by \nJPS \nHere a monkey mother scurries across the temple \ngrounds while carrying her baby. Photo by JPS \n \n \nTourists enjoy some of the many tropical beaches. Photo by JPS  A couple enjoys tea late at night at a roadside hotel \n(restaurant). 1998')]

# %%
len(documents)
# Out:
# 29

# %% [markdown]
# #### **Chunking the Extracted Data**

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def chunking(extracted_documents):
    
    chunking_method = RecursiveCharacterTextSplitter(chunk_size = 135, chunk_overlap = 40)
    documents_cunking = chunking_method.split_documents(extracted_documents)
    
    return documents_cunking


### Chunk size refers to the number of characters or tokens in each piece (chunk) of text that you split your data into.
###    Think of it like cutting a long article into small paragraphs.
###    Example: If chunk size = 800 → each chunk contains 800 characters.



### Chunk overlap means how much content is shared between consecutive chunks.
###    It's used to maintain context between chunks.
###    Example:
###        Chunk 1 → characters 0 to 800
###        Chunk 2 → characters 750 to 1550 (overlap of 50)

### This overlap helps ensure:
###    You don’t cut off a sentence or thought between chunks.
###    The model has some context from the previous chunk.

# %%
chunked_documents = chunking(documents)
chunked_documents
# Out:
# [Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 0, 'page_label': '1'}, page_content='1\nSRI LANKAN FAMILIARIZATION COURSE \nIntroduction To  \nSRI LANKA \n \nGEOGRAPHY'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 0, 'page_label': '1'}, page_content='SRI LANKA \n \nGEOGRAPHY  \n \nSri Lanka is a 25,000 sq mi (65, 610 sq. km) tropical island paradise and a major tourist destination.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 0, 'page_label': '1'}, page_content='e. It is just off the southeastern coast of India between five and 10 degrees north of the equator. It is'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 0, 'page_label': '1'}, page_content='strategically located near Indian Ocean sea lanes. It is slightly larger than West Virginia.  It has a'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 0, 'page_label': '1'}, page_content='beautiful coast line of 1,340 kilometers which attracts a lot of tourists all year around. Sinharaja,'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 0, 'page_label': '1'}, page_content='which is one of world’s protected tropical rain forests, is located in Sri Lanka.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 0, 'page_label': '1'}, page_content='The administrative capital, Sri Jayawardenpura-Kotte, is located near the largest city, Colombo, at'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 0, 'page_label': '1'}, page_content='about 6 degrees north latitude and 79 degrees east longitude.  \n \n \n \nSri Lanka Map Sri Lanka lies off the southeast coast of India.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='2\n         Flag of Sri Lanka \n \nThe flag of Sri Lanka shows a lion holding a sword which signifies that the Sinhalese who are the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='majority belongs to the lion race which is a mythological belief.  The bo leaves at the four corners'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='signify the Buddhist religion which is the religion of the majority of the Sinhalese.  The green stripe'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='to the left signify the Muslim minority and the orange stripe signifies the Tamil minority. \nDescription \n \nCLIMATE'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='Description \n \nCLIMATE  \nThe climate of Sri Lanka is tropical with rains from the northeast monsoon from December to'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='March and southwest monsoon from June to October. The coastal areas are warm and humid but the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='central hills are cooler and less humid. December and January are usually the coolest months and'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='therefore considered the best time of year to visit. Some western slopes receive up to 2500 mm (100'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='inches) of rain per month (not year!), but the leeward slopes in the east and northeast receive little \nrain.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='rain. \nMay is the hottest month, with the heavy monsoon rains soon arriving from the west to cool things'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='down. Nuwara Eliya in the Central Highlands has the lowest mean temperature at 16°C. Contrast'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='that with Trincomalee on the northeast coast, which has a mean temperature of 32° C, sometimes'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='rising to 38 °C. The average yearly temperature for Sri Lanka as a whole is between 28 to 30 °C.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='Due to its proximity to the sea, day and night temperatures may vary by only 4 to 7° C.  \n \nTERRAIN'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='TERRAIN \nSri Lanka is shaped like a pear. Sri Lanka’s terrain is low, flat to rolling plains near the coast, and'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='mountainous at the center.  The mountains are only in the south-central section of the island, the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='highest, Pidurutalagala (Mt Pedro), is 2,524 meters, or 8,281 feet. The many rivers (called gangas'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 1, 'page_label': '2'}, page_content='after India’s Ganges River) are well-fed by the rains. The largest rivers are located in the southwest.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='3\n \nPOPULATION  \nThe population of Sri Lanka in the 2001 census was 18,732,255 giving it a population density of'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='818/square mile. The Human Development index in 2006 was 93rd in the world at .7555 It was'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='estimated that 15% of the population lived in urban areas in 2001 The economic capital, Colombo,'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='is the largest city with a metropolitan population of over 600,000. Other urban centers include: \nDehiwala 209,787 (2001)'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='Dehiwala 209,787 (2001)  \nJaffna 145,600 (1997 estimate)  \nSri Jayawardenepura 115,826 (2001)  \nKandy 110,049 (2001)'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='Kandy 110,049 (2001)  \nGalle 90,934 (2001)'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='Galle 90,934 (2001)  \n \nDue to the civil war, Sri Lanka has a large number of refugees and internally displaced persons.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='They include both Tamils and non-Tamils  and number 500,000-600,000 (2006). After the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='hostilities between the government and armed Tamil separatists began in the mid-1980s, several'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='hundred thousand Tamil civilians have fled the island and more than 200,000 Tamils have sought \nrefuge in the West (July 2006 est.)'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='The largest ethnic groups in Sri Lanka are the Sinhalese at 74%, the Tamils at 18%, and Sri Lankan'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='Moors (descendents of Arab traders) at 7%. Tamils can be further broken down into Indian Tamils'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='and Sri Lankan Tamils.  2001 census data indicates the following breakdown of religious affiliation:'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='Buddhist 69.1%, Muslim 7.6%, Hindu 7.1%, Christian 6.2%, unspecified 10%. Sri Lanka’s'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='Languages include Sinhala (official and national language) 74%, Tamil (national language) 18%,'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='other 8%. English is commonly used in government and is spoken competently by about 10% of the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='population. The level of literacy is 93%. \n \nGOVERNMENT'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='GOVERNMENT   \nThe Sri Lankan government is a democratic socialst republic, with a Western-style parliamentary'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='democracy, has a presidential system of government.  The voting age in Sri Lanka is 18 years.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='President is the head of the state and wields executive power.  He/she is also the commander in'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='chief of the armed forces. He/she is elected by popular vote and holds power for six years. He/she'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='can be re-elected for a second term which is the maximum period for the president.  The legislative'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='power is with the parliament which is also elected for a period of six years but the president has the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='power to dissolve it at any time. The unicameral legislative branch has 225 seats.  Sri Lanka’s'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='judicial branch has a Supreme Court and a Court of Appeals. Judges for both courts are appointed'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='by the president. Sri Lanka also has an independent judiciary which stands as a buffer between the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='President and the parliament.  The President appoints the Prime Minister from the largest party'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='represented in the parliament and also the cabinet.  The President is the head of the cabinet as well.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='Thus, the President of Sri Lanka is very powerful. The current president is Mahinda Rajapakse and'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='the prime mintister is Ratnasiri Wickremanyake, elected in April, 2004.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='There are several political parties that represent all shades of opinion from capitalism, socialism,'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='nationalism, and to Marxism. The main parties are the Sri Lanka Freedom Party (SLFP) which is a'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='social democratic party and the United National Party (UNP) which is a capitalist party.  The'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='Marxists have three main political parties, namely, the Peoples’ Liberation Front, the Equal Society'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 2, 'page_label': '3'}, page_content='Party and the Communist Party of which the People’s Liberation Front (PLF) has now become the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='4\nstrongest. While the PLF is Marxist in orientation, it is also a radical nationalist party mostly of \nSinhalese.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Sinhalese.   \n \nThere are other nationalist parties and pressure groups such as the Jathika Hela Urumaya which is a'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Sinhalese-Buddhist nationalist party, Buddhist clergy, radical chauvinist Sinhalese groups such as'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='the National Movement Against Terrorism, the Tamil Nationalist Alliance (TNA) that is supported'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='by Liberation Tigers of Tamil Elaam (LTTE) which is a terrorist organization that controls parts of'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Northern and Eastern and fighting for a separate state lead by Velupillai PRABHAKARAN, Ceylon'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Workers Congress (CWC) which represents the Tamils of recent Indian origin who live central Sri'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Lanka, Tamil United Liberation Front (TULF) and the Elam Peoples Democratic Party (EPDP). The'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='LTTE doesn’t tolerate political freedom and therefore Tamil democratic parties such as the Tamil'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='United Liberation Front (TULF), Elam Peoples Democratic Party (EPDP) and others are not'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='allowed to function freely in the areas under their control.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='The Tamil minority that forms the majority in the Northern and Eastern provinces is clamoring for'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='autonomy and the LTTE has gone a step further and wants to create a separate state for the Tamils'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='through an armed uprising.  The Sri Lankan state has been fighting the LTTE rebel forces for more'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='than two decades.  The on going armed conflict between the two sides is the main political problem'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='that Sri Lanka faces at present.  Because of the civil war there are reports of human rights violations'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='and racial tension between the majority Sinhalese community and the minority Tamil community.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Over time, most Tamils have come to the realization of the futility of armed conflict and want to'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='reach a peaceful settlement with the government which has agreed to devolve substantial power to'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='the Tamil majority areas.  However, the refusal of the LTTE to agree to government proposals has'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='resulted in a political impasse and continued violence.   \n \nDiplomatic representation in the US\n:'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Diplomatic representation in the US\n: \nChief of mission: Ambassador Bernard GOONETILLEKE'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Chancery: 2148 Wyoming Avenue NW, Washington, DC 20008  \ntelephone: [1] (202) 483-4025 (through 4028)  \nFAX: [1] (202) 232-7181'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='FAX: [1] (202) 232-7181  \nConsulate(s) general: Los Angeles  \nConsulate(s): New York \n \nDiplomatic representation from the US:'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Chief of mission: Ambassador Robert O. BLAKE, Jr.  \nEmbassy: 210 Galle Road, Colombo 3  \nMailing address: P. O. Box 106, Colombo'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 3, 'page_label': '4'}, page_content='Telephone: [94] (11) 249-8500  \nFAX: [94] (11) 243-7345'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='5\nHISTORY \n \nA Thumbnail Description of Sri Lanka’s History'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='The Sinhalese arrived in Sri Lanka late in the 6th century B.C.E., probably from northern India.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='Buddhism was introduced beginning in about the mid-third century B.C.E. (see religion, below),'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='and a great civilization developed at the cities of Anuradhapura (kingdom from circa 200 B.C.E. to'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='circa C.E. 1000) and Polonnaruwa (from about 1070 to 1200). In the 14th century, a south Indian'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='dynasty seized power in the north and established a Tamil kingdom. Occupied by the Portuguese in'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='the 16th century and by the Dutch in the 17th century, the island was ceded to the British in 1796,'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='became a crown colony in 1802, and was united under British rule by 1815. As Ceylon, it became'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 4, 'page_label': '5'}, page_content='independent in 1948; its name was changed to Sri Lanka in 1972.'),
# ...
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 26, 'page_label': '27'}, page_content='7283 & 81-223-8901, Fax: +94 81-222-3679. \nThe BPS distubuter in the US is Pariyatti, http://www.pariyatti.com/.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='28\nTOURISM \nThe climate, environment, history and warmth of the people help to make Sri Lanka an inviting'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='place to visit. We have prepared the following general advice for travelers to Sri Lanka. Because of'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='the civil war, it is recommended to review sources that are consistently updated on Sri Lanka’s \nconditions.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='conditions.   \nForeign tourists have not been targeted by violence in Sri Lanka, but could become victims to it'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='inadvertently. Until late 2006 terrorist and war activities seldom reached outside of the northern and'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='eastern parts of the island, with the occasional attack in Colombo. Violent activity has now'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='increased in tourist areas in the south and central regions of the island. A bright spot is that'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='foreigners willing to travel in Sri Lanka might appreciate the reduction in other visitors brought'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='about by the war and the tsunami.  \n \nLocal customs'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='Local customs \nStandards of dress and behavior are usually more conservative than in western countries. For'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='instance, when visiting places such as temples you should cover your legs. Take care when'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='doing activities such as photographing statues of the Buddha. You should receive permission'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='and ask for guidelines when doing so (e.g. you may be asked to not have people in the photo \nwith the statue). \nHealth Issues'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='with the statue). \nHealth Issues \nMany food-borne, water-borne and other infectious diseases such as typhoid, hepatitis and'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='rabies can be prevented by vaccinations. Others, such as malaria, dengue fever, chikungunya'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='fever, Japanese encephalitis and filariasis, can be prevented by avoiding mosquito bites. There'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='is malaria risk in all areas, except for the districts of Colombo, Galle, Kalutara, and Nuwara \nEliya.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='Eliya.  \nThe Ministry of Healthcare and Nutrition in Sri Lanka recently confirmed cases of'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='chikungunya fever in patients from several districts; the most affected districts are Batticaloa,'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='Colombo, Jaffna, Kalmunai, Mannar, Puttalam, and Trincomalee. Surveillance activities for'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='chikungunya fever cases are continuing in sentinel hospitals in Sri Lanka. There are no'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='preventive medications or FDA-approved vaccines for chikungunya fever, but travelers can'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='take steps to reduce their risk of being bitten by infected mosquitoes. \nThere have been no recent outbreaks in polio and avian flu.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='Local Laws \nTake care to observe all local laws. There are penalties for drug trafficking and homosexual'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='acts. It is prohibited to take photos and video tape in high security zones (HSZs) such as some'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 27, 'page_label': '28'}, page_content='government buildings and military establishments.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 28, 'page_label': '29'}, page_content='29\nMonkeys are very common the Ancient city Anurahdapura where tourisst and pilgrims visits.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 28, 'page_label': '29'}, page_content='Offering of flowers to the Buddha by pilgrims are visited by a \ncommon monkey in the area and a boy from USA. Photo by \nJPS'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 28, 'page_label': '29'}, page_content='JPS \nHere a monkey mother scurries across the temple \ngrounds while carrying her baby. Photo by JPS'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 28, 'page_label': '29'}, page_content='Tourists enjoy some of the many tropical beaches. Photo by JPS  A couple enjoys tea late at night at a roadside hotel'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'creationdate': '2008-01-18T11:47:46-08:00', 'author': 'user', 'company': 'Central Texas College', 'moddate': '2015-03-06T16:10:22-08:00', 'title': 'Urdu Introduction – information needed:', 'source': 'INTRODUCTION.pdf', 'total_pages': 29, 'page': 28, 'page_label': '29'}, page_content='(restaurant). 1998')]

# %%
len(chunked_documents)             #### number of chunkes
# Out:
# 376

# %% [markdown]
# ## **Indexing**

# %% [markdown]
# #### **Selecting the Embedding Model**

# %% [markdown]
# #### Select and Download an Embedding Model from Hugging Face

# %%
"""
from langchain_community.embeddings import SentenceTransformerEmbeddings

embedding_model = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
"""
# Out:
# '\nfrom langchain_community.embeddings import SentenceTransformerEmbeddings\n\nembedding_model = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")\n'

# %% [markdown]
# #### Save the Selected Embedding Model in locally

# %%
"""
embedding_model_path = "./local_embedding_model"
sentence_transformer_model = embedding_model.client   # Access the underlying SentenceTransformer model inside LangChain's wrapper
sentence_transformer_model.save(embedding_model_path)
"""
# Out:
# '\nembedding_model_path = "./local_embedding_model"\nsentence_transformer_model = embedding_model.client   # Access the underlying SentenceTransformer model inside LangChain\'s wrapper\nsentence_transformer_model.save(embedding_model_path)\n'

# %% [markdown]
# #### Load the Saved Embedding Model

# %%
from langchain.embeddings import SentenceTransformerEmbeddings

embedding_model_path = "./local_embedding_model"
embedding_model = SentenceTransformerEmbeddings(model_name=embedding_model_path)  # Load from local path


### Hugging Face is an open-source platform and company that provides tools, models, datasets, and infrastructure for building machine 
### learning (especially natural language processing) applications — with a strong focus on Large Language Models (LLMs).

# %% [markdown]
# #### Check the Embedding Model

# %%
example_embedding = embedding_model.embed_query("Hello world")
example_embedding
# Out:
# [-0.03447731211781502,
#  0.03102317824959755,
#  0.006734973285347223,
#  0.026108987629413605,
#  -0.03936202451586723,
#  -0.16030248999595642,
#  0.06692396104335785,
#  -0.006441520527005196,
#  -0.047450557351112366,
#  0.014758833684027195,
#  0.0708753690123558,
#  0.05552764981985092,
#  0.019193340092897415,
#  -0.026251304894685745,
#  -0.010109521448612213,
#  -0.026940487325191498,
#  0.022307438775897026,
#  -0.022226588800549507,
#  -0.1496925950050354,
#  -0.017493003979325294,
#  0.007676261477172375,
#  0.054352227598428726,
#  0.003254449460655451,
#  0.031725913286209106,
#  -0.0846213772892952,
#  -0.029406029731035233,
#  0.05159557983279228,
#  0.0481240414083004,
#  -0.0033148375805467367,
#  -0.05827924236655235,
#  0.041969284415245056,
#  0.02221062034368515,
#  0.1281888782978058,
#  -0.0223389845341444,
#  -0.01165628433227539,
#  0.06292835623025894,
#  -0.03287626802921295,
#  -0.09122604876756668,
#  -0.031175415962934494,
#  0.052699532359838486,
#  0.047034814953804016,
#  -0.08420310914516449,
#  -0.030056163668632507,
#  -0.02074483595788479,
#  0.009517813101410866,
#  -0.0037217980716377497,
#  0.007343285717070103,
#  0.03932429477572441,
#  0.0932740569114685,
#  -0.0037885350175201893,
#  -0.052742063999176025,
#  -0.058058153837919235,
#  -0.006864337716251612,
#  0.0052832551300525665,
#  0.08289296925067902,
#  0.019362807273864746,
#  0.006284500006586313,
#  -0.010330778546631336,
#  0.00903239380568266,
#  -0.037683747708797455,
#  -0.045206066220998764,
#  0.024016303941607475,
#  -0.0069441781379282475,
#  0.013491650111973286,
#  0.10005493462085724,
#  -0.07168389111757278,
#  -0.02169506996870041,
#  0.031618401408195496,
#  -0.05163465067744255,
#  -0.08224773406982422,
#  -0.06569328159093857,
#  -0.009895375929772854,
#  0.005816361401230097,
#  0.07355453819036484,
#  -0.034050364047288895,
#  0.02488611452281475,
#  0.014488056302070618,
#  0.026457369327545166,
#  0.00965674128383398,
#  0.030217239633202553,
#  0.05280391499400139,
#  -0.07535986602306366,
#  0.009897153824567795,
#  0.029836812987923622,
#  0.017555557191371918,
#  0.023091940209269524,
#  0.0019338299753144383,
#  0.0014001906383782625,
#  -0.04717596247792244,
#  -0.011194327846169472,
#  -0.11420147120952606,
#  -0.01981198787689209,
#  0.040266215801239014,
#  0.002193022985011339,
#  -0.07979222387075424,
#  -0.025382284075021744,
#  0.09448298066854477,
#  -0.028981085866689682,
#  -0.1450025737285614,
#  0.230977401137352,
#  0.02773120068013668,
#  0.03211146593093872,
#  0.03106500953435898,
#  0.04283283278346062,
#  0.0642378181219101,
#  0.03216314688324928,
#  -0.0048767817206680775,
#  0.05569946765899658,
#  -0.037532348185777664,
#  -0.021505512297153473,
#  -0.028342638164758682,
#  -0.028846943750977516,
#  0.038353078067302704,
#  -0.017468715086579323,
#  0.052485331892967224,
#  -0.07487603276968002,
#  -0.03125973045825958,
#  0.02184157446026802,
#  -0.039895687252283096,
#  -0.00858709029853344,
#  0.02695663459599018,
#  -0.04849553480744362,
#  0.011469831690192223,
#  0.029618138447403908,
#  -0.02057218924164772,
#  0.01310389768332243,
#  0.02883351594209671,
#  -3.194199452164203e-33,
#  0.06478209793567657,
#  -0.018130220472812653,
#  0.05178998038172722,
#  0.12198270112276077,
#  0.02878020517528057,
#  0.008721970021724701,
#  -0.07052116841077805,
#  -0.016907284036278725,
#  0.040739674121141434,
#  0.042116180062294006,
#  0.025447173044085503,
#  0.0357462540268898,
#  -0.04914474114775658,
#  0.0021289787255227566,
#  -0.015546582639217377,
#  0.05073050409555435,
#  -0.048185285180807114,
#  0.035880643874406815,
#  -0.004067054949700832,
#  0.101724773645401,
#  -0.05597003176808357,
#  -0.010681074112653732,
#  0.011235786601901054,
#  0.09068652987480164,
#  0.004234453663229942,
#  0.03513862565159798,
#  -0.009702873416244984,
#  -0.09386517107486725,
#  0.09285556524991989,
#  0.008004934526979923,
#  -0.007705419324338436,
#  -0.0520867183804512,
#  -0.012588017620146275,
#  0.00326690380461514,
#  0.0060135056264698505,
#  0.007581575307995081,
#  0.010517150163650513,
#  -0.0863456130027771,
#  -0.06987879425287247,
#  -0.002533906139433384,
#  -0.09097658842802048,
#  0.04688728600740433,
#  0.0520765595138073,
#  0.007193839643150568,
#  0.010903693735599518,
#  -0.00522950803861022,
#  0.013937314040958881,
#  0.02196834422647953,
#  0.03420867398381233,
#  0.06022470071911812,
#  0.0001166390793514438,
#  0.014731952920556068,
#  -0.07008925825357437,
#  0.028499074280261993,
#  -0.0276016928255558,
#  0.010768451727926731,
#  0.03483094274997711,
#  -0.022487912327051163,
#  0.009769005700945854,
#  0.07722780853509903,
#  0.021588366478681564,
#  0.11495624482631683,
#  -0.06800119578838348,
#  0.023760994896292686,
#  -0.015983907505869865,
#  -0.017826946452260017,
#  0.06439489126205444,
#  0.03202572092413902,
#  0.05027028173208237,
#  -0.0059137591160833836,
#  -0.03370799869298935,
#  0.017840279266238213,
#  0.016573350876569748,
#  0.06329656392335892,
#  0.03467720001935959,
#  0.04647345095872879,
#  0.09790614992380142,
#  -0.006635518278926611,
#  0.02520708739757538,
#  -0.07798828929662704,
#  0.016926469281315804,
#  -0.0009458194253966212,
#  0.022471891716122627,
#  -0.03825322538614273,
#  0.0957048162817955,
#  -0.005350869614630938,
#  0.01046911533921957,
#  -0.11524050682783127,
#  -0.013262545689940453,
#  -0.010709461756050587,
#  -0.08311726897954941,
#  0.07327358424663544,
#  0.049392230808734894,
#  -0.008994300849735737,
#  -0.0958455353975296,
#  3.366148194408595e-33,
#  0.12493181973695755,
#  0.019349703565239906,
#  -0.058225732296705246,
#  -0.035988230258226395,
#  -0.05074665695428848,
#  -0.045662377029657364,
#  -0.0826033502817154,
#  0.1481947898864746,
#  -0.08842121064662933,
#  0.06027445197105408,
#  0.051030177623033524,
#  0.010303189978003502,
#  0.14121417701244354,
#  0.030813761055469513,
#  0.06103314831852913,
#  -0.052851274609565735,
#  0.13664892315864563,
#  0.009189927950501442,
#  -0.017325185239315033,
#  -0.012848593294620514,
#  -0.007995285093784332,
#  -0.05098006874322891,
#  -0.052350662648677826,
#  0.00759302731603384,
#  -0.015166300348937511,
#  0.016960330307483673,
#  0.021270543336868286,
#  0.0205580685287714,
#  -0.1200280711054802,
#  0.014461836777627468,
#  0.02675989456474781,
#  0.025330718606710434,
#  -0.0427546501159668,
#  0.006768449209630489,
#  -0.01445857249200344,
#  0.04526199400424957,
#  -0.09147650003433228,
#  -0.01943916641175747,
#  -0.017833471298217773,
#  -0.054910145699977875,
#  -0.0526411198079586,
#  -0.010459044016897678,
#  -0.052016060799360275,
#  0.020891981199383736,
#  -0.0799703299999237,
#  -0.012111322954297066,
#  -0.057731445878744125,
#  0.023178262636065483,
#  -0.008031759411096573,
#  -0.025989310815930367,
#  -0.07995667308568954,
#  -0.020728813484311104,
#  0.048817671835422516,
#  -0.02038913406431675,
#  -0.04917658865451813,
#  0.014159612357616425,
#  -0.06362205743789673,
#  -0.007807374000549316,
#  0.01643153466284275,
#  -0.02568250335752964,
#  0.01338114682585001,
#  0.026248808950185776,
#  0.0099784005433321,
#  0.06322887539863586,
#  0.002672202419489622,
#  -0.00658275606110692,
#  0.016631953418254852,
#  0.03236645832657814,
#  0.03794245421886444,
#  -0.03637607395648956,
#  -0.006910937838256359,
#  0.00015965115744620562,
#  -0.0016335442196577787,
#  -0.027278153225779533,
#  -0.02803810127079487,
#  0.049681406468153,
#  -0.028867190703749657,
#  -0.002418102463707328,
#  0.014774877578020096,
#  0.009764549322426319,
#  0.005797612946480513,
#  0.013486173003911972,
#  0.00556789617985487,
#  0.037227097898721695,
#  0.007232548203319311,
#  0.04015627130866051,
#  0.08150327950716019,
#  0.07199166715145111,
#  -0.013056166470050812,
#  -0.04288201779127121,
#  -0.011011218652129173,
#  0.004897876176983118,
#  -0.009229711256921291,
#  0.03519148379564285,
#  -0.051035076379776,
#  -1.571437557856825e-08,
#  -0.08862440288066864,
#  0.023909302428364754,
#  -0.016238775104284286,
#  0.03170047327876091,
#  0.02728421427309513,
#  0.05246880650520325,
#  -0.04707099869847298,
#  -0.05884748324751854,
#  -0.0632081851363182,
#  0.04088853299617767,
#  0.04982797056436539,
#  0.10655171424150467,
#  -0.0745023712515831,
#  -0.012495407834649086,
#  0.01837071031332016,
#  0.039474066346883774,
#  -0.02479787915945053,
#  0.014516271650791168,
#  -0.037069179117679596,
#  0.02001570537686348,
#  -4.8563404561718926e-05,
#  0.009866608306765556,
#  0.024838725104928017,
#  -0.05245814844965935,
#  0.029314178973436356,
#  -0.08719188719987869,
#  -0.014499709941446781,
#  0.026019109413027763,
#  -0.018746372312307358,
#  -0.07620518654584885,
#  0.03504328802227974,
#  0.10363949090242386,
#  -0.028050506487488747,
#  0.012718159705400467,
#  -0.0763254314661026,
#  -0.018652357161045074,
#  0.024976719170808792,
#  0.08144529908895493,
#  0.06875880062580109,
#  -0.0640566274523735,
#  -0.08389382064342499,
#  0.06136235594749451,
#  -0.03354553133249283,
#  -0.10615334659814835,
#  -0.04008055850863457,
#  0.03253019601106644,
#  0.07662481814622879,
#  -0.0730162262916565,
#  0.0003375552187208086,
#  -0.04087163507938385,
#  -0.0757884606719017,
#  0.027527639642357826,
#  0.0746254250407219,
#  0.017717270180583,
#  0.09121847152709961,
#  0.11022016406059265,
#  0.0005698120803572237,
#  0.05146334692835808,
#  -0.0145513154566288,
#  0.03323206678032875,
#  0.023792287334799767,
#  -0.022889845073223114,
#  0.0389375202357769,
#  0.03020685911178589]

# %%
vector_dimension = len(example_embedding)    ### This length should be same as pinecone vector DB dimension
vector_dimension
# Out:
# 384

# %% [markdown]
# #### **Create the Pinecone Vector DB**

# %% [markdown]
# #### Load the Evironment Variables

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# #### Create a Connection with the Pinecone Account

# %%
from pinecone import Pinecone
import os 

pinecone_api_key = os.getenv("PINECONE_API_KEY")           #### select the pinecone API key
pinecone_client = Pinecone(api_key=pinecone_api_key)       #### Now create the connection under this pinecone API key

### The Pinecone() function requires you to pass the pinecone api key as a string, and it doesn’t automatically read from environment variables

# %% [markdown]
# #### Create the Index If not Created Under Selected Pinecone connection

# %%
from pinecone import ServerlessSpec

index_name = "sri-lanka-informations"

if not pinecone_client.has_index(index_name):
    pinecone_client.create_index(
        name=index_name,
        dimension=vector_dimension,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )


### index = pinecone_client.Index(index_name)  This creates a connection to your existing or created Pinecone index
### it is necessary if you want to interact with the index after creating it below as:
###   Insert (upsert) vectors
###   Search (query) vectors
###   Delete vectors
###   Update vectors

### Examle:
### index.upsert(vectors=your_data)

# %% [markdown]
# #### **Embedding the Chunked Documents and Upload into Pinecoe Vctor DB**

# %%
"""
from langchain_pinecone import PineconeVectorStore

vectorstore = PineconeVectorStore.from_documents(
    documents=chunked_documents,
    embedding=embedding_model,
    index_name=index_name
)
"""
### * We don't need write pinecone_api_key = pinecone_api_key in PineconeVectorStore.from_documents() because when we use langchain_pinecone and load_dotenv()
### then it automatically select the pinecone api key from .env file.

### More we don't need to use index = pinecone_client.Index(index_name) to take the access for changing the index. Because when we use PineconeVectorStore in
### langchain_pinecone then it automatically does the following under the hood:
###   1.Initializes the Pinecone client using the API key and environment (discribe as *)
###   2.Connects to the index with the name you provided (index_name)
###   3.Upserts (uploads) your document embeddings
###   4.And finally, returns a LangChain-compatible retriever

### So you don’t need to manually call:
### pinecone_client = Pinecone(...)
### index = pinecone_client.Index(index_name)
# Out:
# '\nfrom langchain_pinecone import PineconeVectorStore\n\nvectorstore = PineconeVectorStore.from_documents(\n    documents=chunked_documents,\n    embedding=embedding_model,\n    index_name=index_name\n)\n'

# %% [markdown]
# ## **Defining the Retrieval Request**

# %% [markdown]
# #### Import the Created Index in Pinecode Vector DB

# %%
from langchain_pinecone import PineconeVectorStore

import_index = PineconeVectorStore.from_existing_index(
    index_name= "sri-lanka-informations",
    embedding= embedding_model
)

### We don't need write pinecone_api_key = pinecone_api_key in PineconeVectorStore.from_existing_index() because when we use langchain_pinecone and load_dotenv()
### then it automatically select the pinecone api key from .env file.

### So you don’t need to manually call:
### pinecone_client = Pinecone(...)
### index = pinecone_client.Index(index_name)

# %% [markdown]
# #### Create a Retriever Connection

# %%
retriever = import_index.as_retriever(search_type = "similarity", search_kwargs = {"k":3})

### that line is where you turn your Pinecone index connection into a Retriever object that LangChain can use in your RAG 
### pipeline.

### search_type="similarity"
### Means the retriever will find chunks whose vector embeddings are most similar to the user query embedding.

### search_kwargs={"k": 3}
### Means "return the top 3 most similar chunks".
### If your chunk size is ~400 tokens and k=3 → your LLM will get about 1,200 tokens as your retrieved context.

### 3️⃣ Why This Step is Important
### The retriever is the bridge between:
###    Your stored document embeddings in Pinecone.
###    Your question-answering chain (LLM + prompt).
### When the user asks a question:
###    Retriever turns the question into an embedding vector.
###    Looks up the closest k vectors in Pinecone.
###    Returns those chunks as {context} for the LLM.

# %% [markdown]
# #### Check the Created Retriever

# %%
retriever.invoke("How climate of Sri Lanka?")
# Out:
# [Document(id='212f01c6-4bca-469d-be31-10828898cbf0', metadata={'author': 'user', 'company': 'Central Texas College', 'creationdate': '2008-01-18T11:47:46-08:00', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'moddate': '2015-03-06T16:10:22-08:00', 'page': 1.0, 'page_label': '2', 'producer': 'Acrobat Distiller 6.0 (Windows)', 'source': 'INTRODUCTION.pdf', 'title': 'Urdu Introduction – information needed:', 'total_pages': 29.0}, page_content='Description \n \nCLIMATE  \nThe climate of Sri Lanka is tropical with rains from the northeast monsoon from December to'),
#  Document(id='dce9d650-0879-43a1-8fd7-379bd0cfe680', metadata={'author': 'user', 'company': 'Central Texas College', 'creationdate': '2008-01-18T11:47:46-08:00', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'moddate': '2015-03-06T16:10:22-08:00', 'page': 1.0, 'page_label': '2', 'producer': 'Acrobat Distiller 6.0 (Windows)', 'source': 'INTRODUCTION.pdf', 'title': 'Urdu Introduction – information needed:', 'total_pages': 29.0}, page_content='rising to 38 °C. The average yearly temperature for Sri Lanka as a whole is between 28 to 30 °C.'),
#  Document(id='003df3ba-e10c-48be-bdd6-93b9da35fa8f', metadata={'author': 'user', 'company': 'Central Texas College', 'creationdate': '2008-01-18T11:47:46-08:00', 'creator': 'Acrobat PDFMaker 6.0 for Word', 'moddate': '2015-03-06T16:10:22-08:00', 'page': 0.0, 'page_label': '1', 'producer': 'Acrobat Distiller 6.0 (Windows)', 'source': 'INTRODUCTION.pdf', 'title': 'Urdu Introduction – information needed:', 'total_pages': 29.0}, page_content='about 6 degrees north latitude and 79 degrees east longitude.  \n \n \n \nSri Lanka Map Sri Lanka lies off the southeast coast of India.')]

# %% [markdown]
# ## **Preparing the LLM**

# %% [markdown]
# #### **Selecting the LLM**

# %% [markdown]
# #### Login to the Hugging Face

# %%
from huggingface_hub import login

login(os.getenv("HUGGINGFACE_HUB_TOKEN"))

### The login() function requires you to pass the token as a string, and it doesn’t automatically read from environment variables

# %% [markdown]
# #### Selecting and Download the LLM from Hugging Face

# %%
"""
from transformers import pipeline

LLM_name = "google/flan-t5-base"
chatmodel = pipeline(task = "text2text-generation", model = LLM_name)
"""


### "text2text-generation" is a task type in Hugging Face’s transformers library. It tells the pipeline() that the model takes text 
### input and produces text output.

### These models are trained to treat everything as a text-in → text-out problem. That includes:
###    Translation
###    Question answering
###    Summarization
###    Explanation
###    Instruction 

### Example:
### response = chatmodel("Translate English to French: I love you.")
### print(response[0]["generated_text"])
### Output: "Je t'aime"

### Text task
#| Task                         | Description                                                    | Example Models            |
#| ---------------------------- | -------------------------------------------------------------- | ------------------------- |
#| `"text-classification"`      | Classifies text into categories (e.g., sentiment analysis)     | BERT, RoBERTa, DistilBERT |
#| `"zero-shot-classification"` | Classify text into user-defined labels without retraining      | BART, RoBERTa             |
#| `"text-generation"`          | Generate text from a prompt (like ChatGPT-style completion)    | GPT-2, GPT-J, Mistral     |
#| `"text2text-generation"`     | Text in → Text out (used for T5-like models)                   | T5, FLAN-T5, BART         |
#| `"translation"`              | Translate text between languages                               | MarianMT, Helsinki-NLP    |
#| `"summarization"`            | Summarize long text into short form                            | BART, T5                  |
#| `"question-answering"`       | Extract answer from context given a question                   | BERT, DistilBERT          |
#| `"conversational"`           | Multi-turn dialogue (e.g., for chatbots)                       | Blenderbot, DialoGPT      |
#| `"fill-mask"`                | Predict missing words in a sentence (masked language modeling) | BERT, RoBERTa             |

### Image task
#| Task                     | Description                    | Example Models      |
#| ------------------------ | ------------------------------ | ------------------- |
#| `"image-classification"` | Classifies image content       | ViT, ConvNeXt       |
#| `"object-detection"`     | Detects objects in an image    | DETR, YOLO, OWL-ViT |
#| `"image-segmentation"`   | Labels each pixel of an image  | SegFormer, DPT      |
#| `"image-to-text"`        | Generates captions from images | BLIP, GIT           |

### Audio task
#| Task                             | Description                                 | Example Models    |
#| -------------------------------- | ------------------------------------------- | ----------------- |
#| `"automatic-speech-recognition"` | Converts spoken audio to text               | Whisper, Wav2Vec2 |
#| `"audio-classification"`         | Classifies sound type (e.g., music, speech) | Wav2Vec2, Hubert  |

### Multimodel task
#| Task                            | Description                             | Example Models  |
#| ------------------------------- | --------------------------------------- | --------------- |
#| `"document-question-answering"` | Answer questions from scanned documents | Donut, LayoutLM |
#| `"visual-question-answering"`   | Answer questions based on an image      | OFA, BLIP       |
# Out:
# '\nfrom transformers import pipeline\n\nLLM_name = "google/flan-t5-base"\nchatmodel = pipeline(task = "text2text-generation", model = LLM_name)\n'

# %% [markdown]
# #### Saving the Downloaded LLM

# %%
"""
### Saving path
LLM_path = "./flan-t5-base-local"

### Save the model
model = chatmodel.model
model.save_pretrained(LLM_path)

### Save the tokenizer
tokenizer = chatmodel.tokenizer
tokenizer.save_pretrained(LLM_path)

"""

### 🔤 What Is a Tokenizer?
###    A tokenizer is a tool that converts text into tokens — which are smaller chunks (like words or subwords) — so that language models
###    like ChatGPT or Flan-T5 can understand and process them.

### 🧠 Why Do We Need a Tokenizer?
###    Machine learning models don’t understand text directly — they only understand numbers.
###    So, a tokenizer does two key jobs:
###    Text → Tokens → Numbers (for input to the model)
###    Numbers → Tokens → Text (for decoding the model’s output)

### Saving a tokenizer = saving the text-to-token logic so your model can use it again and again without relying on downloading from 
###  Hugging Face.
# Out:
# '\n### Saving path\nLLM_path = "./flan-t5-base-local"\n\n### Save the model\nmodel = chatmodel.model\nmodel.save_pretrained(LLM_path)\n\n### Save the tokenizer\ntokenizer = chatmodel.tokenizer\ntokenizer.save_pretrained(LLM_path)\n\n'

# %% [markdown]
# #### Loading the Saved LLM

# %%
from transformers import pipeline

LLM_path = "./flan-t5-base-local"

loaded_LLM = pipeline(task="text2text-generation", model= LLM_path, max_new_tokens = 100)
# Out:
# Device set to use cpu

# %% [markdown]
# #### Convert Hugging Face Model into Langchain-Compatible Object

# %%
from langchain_huggingface import HuggingFacePipeline

#chatmodel = HuggingFacePipeline(pipeline=loaded_LLM)
chatmodel = HuggingFacePipeline(pipeline=loaded_LLM)

### When we use a LLM from Hugging Face pipeline (like one created with transformers.pipeline) then it cannot be used
### with RAG workflow inside the LangChain (a framework to build applications using LLMs.)
 

### The HuggingFacePipeline class inside huggingface modulle of LangChain library provides facility for your loaded_LLM 
### pipeline model works as a LangChain-compatible object. Then you can now use it in:
###   RAG chains
###   Prompt templates
###   Document chains
###   Retrieval chains

# %% [markdown]
# #### Defining the Input Structure of the LLM

# %%
from langchain.prompts import PromptTemplate

system_prompt = """
You are an assistant that answers questions about Sri Lanka.

Instructions:
1. Use ONLY the information from the document 'Introduction to Sri Lanka'.
2. The document covers: geography, history, culture, economy, religion, transportation, health care, education, and society.
3. Do NOT use outside knowledge or make up information.
4. Answer in EXACTLY complete and clear sentences.
5. If the answer is not found in the document, reply:
   "The document does not provide this information."

Context:
{context}

Question:
{input}

Answer:
"""

prompt = PromptTemplate(
    input_variables=["context", "input"],
    template=system_prompt.strip()
)



### This is the template we follow to give inputs to the LLM. This template contains both user's question informations 
### and the guidance which LLM should follow when give the answer. This guidence gives a chance to handle LLM model.

### When user ask a question then the question is send through {input} and it's corresponding retrievel which gives 
### from pinecone vector DB joined together as one block of text (not as separate {chunk1},{chunk2}, {chunk3}
### variables) and send it through {context} into system_prompt then the input sttructure of the LLM below as:

"""
You are an assistant that answers questions about Sri Lanka.

Instructions:
1. Use ONLY the information from the document 'Introduction to Sri Lanka'.
2. The document covers: geography, history, culture, economy, religion, transportation, health care, education, and society.
3. Do NOT use outside knowledge or make up information.
4. Answer in EXACTLY three complete and clear sentences.
5. If the answer is not found in the document, reply:
   "The document does not provide this information."

Context:
[retrieved chunk 1 text]
[retrieved chunk 2 text]
[retrieved chunk 3 text]

Question: 
What is XYZ?
"""
# Out:
# '\nYou are an assistant that answers questions about Sri Lanka.\n\nInstructions:\n1. Use ONLY the information from the document \'Introduction to Sri Lanka\'.\n2. The document covers: geography, history, culture, economy, religion, transportation, health care, education, and society.\n3. Do NOT use outside knowledge or make up information.\n4. Answer in EXACTLY three complete and clear sentences.\n5. If the answer is not found in the document, reply:\n   "The document does not provide this information."\n\nContext:\n[retrieved chunk 1 text]\n[retrieved chunk 2 text]\n[retrieved chunk 3 text]\n\nQuestion: \nWhat is XYZ?\n'

# %% [markdown]
# #### Combining Retrieved Documents, User Question, and Instructions and pass to the LLM

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain


question_answer_chain = create_stuff_documents_chain(chatmodel, prompt)

### What create_stuff_documents_chain does:
###    Think of it as a glue function between your retrieved documents and your LLM prompt.

### This glue function work as below:
###   1. When retriever gives you chunks from Pinecone:
###      Those chunks are LangChain Document objects with .page_content (text) and optional metadata.
###      You can't just "throw" them at the LLM — they need to be merged into the {context} placeholder in your prompt.

###   2. create_stuff_documents_chain does this merging automatically:
###      Joins all chunk texts together into one block ({context}).
###      Inserts that block into the prompt.
###      Sends the final, filled-in prompt to your chatmodel (LLM).
###      Collects the LLM's output as your answer

# %% [markdown]
# ## **Connecting the Prepeared LLM with Pinecone Vector DB**

# %%
from langchain.chains import create_retrieval_chain

rag_chain = create_retrieval_chain(retriever, question_answer_chain)


### 2️⃣ Purpose of create_retrieval_chain()
### It combines:
###    The retrieval step (search Pinecone for relevant chunks).
###    The generation step (pass chunks + question + prompt to LLM via question_answer_chain).
### You get a single callable object (rag_chain) that:
###    Takes a user’s question.
###    Automatically retrieves top-k chunks.
###    Passes them + question + prompt into your LLM.
###    Returns the final grounded answer.

# %% [markdown]
# #### Check the Connection from a User Input

# %%
response = rag_chain.invoke({"input":"How climate of Sri Lanka?"})
print(response["answer"])
# Out:
# tropical

# %% [markdown]
# #### Errors

# %%
### TypeError: messages=[SystemMessage(...), HumanMessage(...)] have the wrong format...

### ✅ Why This Happens
### The error is occurring because chatmodel = pipeline(...) from Hugging Face Transformers is not compatible with LangChain's chat 
### interface, especially when used with ChatPromptTemplate, which generates chat-style messages (SystemMessage, HumanMessage, etc).
### However, you're using create_stuff_documents_chain() which expects the model to be a LangChain-compatible LLM — not a Hugging Face pipeline.

### ✅ Solution: Use HuggingFacePipeline with LangChain
### You need to wrap your Hugging Face pipeline into a LangChain-compatible model using HuggingFacePipeline.

### from langchain.llms import HuggingFacePipeline

# Load HF model locally
#local_dir = "./flan-t5-base-local"
#hf_pipeline = pipeline(task="text2text-generation", model=local_dir)

# Wrap the HF pipeline to be LangChain-compatible
#chatmodel = HuggingFacePipeline(pipeline=hf_pipeline)

# %%
### Token indices sequence length is longer than the specified maximum sequence length for this model (629 > 512)

### ✅ Why This Happens
### flan-t5-base only supports up to 512 tokens. But LangChain's RAG pipeline combines retrieved documents and your question into one 
### input. If that combined input exceeds 512 tokens, you get:

### ✅ How to Fix It
### You need to limit the total number of tokens or limit the number of retrieved documents passed to the model. Here are 3 effective
### solutions:
###  Solution 1: Limit number of retrieved documents
###  Solution 2: Truncate context before sending to model
###  Solution 3: Use a larger model (if needed)

# %% [markdown]
# #### Notes

# %%
### Retrieval-Augmented Generation (RAG) is a method that improves the accuracy and relevance of LLM responses by combining 
### an external knowledge source (like a vector database) with the model’s generation ability. Instead of relying only on the
### LLM’s internal knowledge, RAG retrieves relevant facts from your dataset and feeds them into the model at query time.

### 🎯 Core Purpose of RAG:
###    Enhance accuracy → Avoids hallucinations by grounding answers in real documents.
###    Keep answers up-to-date → You can update your database without retraining the LLM.
###    Make answers domain-specific → Tailors the LLM to a particular topic or dataset.
###    Improve trust → Sources can be shown to the user for transparency.

### ⚙️ Core Steps of RAG
###     1. Data Preprocessing
###          Load data, data cleaning, data extracting (eg. PDFs, websites)
###     2. Indexing
###          Selecting embedding model, Create Pinecone vector DB, embedding chunked data and store in pinecone vector DB.
###     3. Defining the retrievel reqquest
###     4. Preparing the LLM
###     5. Connecting prepared LLM with Pinecone vector DB
###     6. Check the connection

# %%
### When you're developing an LLM-based chatbot, especially one focused on domains like medicine, the reliability of the chatbot’s 
### output depends on several important factors. Here's a breakdown of the key elements:

### ✅ 1. Quality and Relevance of the Data (Documents / Knowledge Base)
###    Garbage in, garbage out applies here.
###    If your chatbot is connected to a vector database (like Pinecone), the quality of the documents you upload directly affects the accuracy.
###    For example: Uploading a clear, verified Diagnostic Tests Guide PDF will result in better answers than using random or outdated internet content.

### ✅ 2. Prompt Engineering
###    The system prompt or instructions you give the LLM heavily guide how it responds.
###    For example:
###       "You are a medical assistant. Use the retrieved context to answer the user question concisely. If unsure, say you don't know."
###    Good prompts improve relevance, safety, and structure of output.

### ✅ 3. LLM Capability (Model Power)
###    Model size, training data, and architecture matter.
###    Example:
###        google/flan-t5-base is small (~250M params), so it's faster and cheaper but less accurate and less expressive.
###        GPT-4o or Mistral 7B are much stronger at understanding nuanced queries and giving richer answers.

### ✅ 4. Context Window and Chunk Size
###    If your LLM has a context limit of 512 tokens (like flan-t5-base), it may not understand or process long questions or multiple retrieved chunks.
###    Larger models like GPT-4o support 128k tokens, so they handle long context better.

### ✅ 5. Retrieval Quality (if using RAG)
###    If you're using Retrieval-Augmented Generation (RAG) with vector stores like Pinecone, the chatbot’s answer depends on the retrieved chunks.
###    Influenced by:
###        Embedding model quality (e.g., all-MiniLM-L6-v2)
###        Vector dimension match
###        Chunking strategy (chunk size, overlap, etc.)
###        Query rewriting / rephrasing to improve retrieval

# %%
### ❓ If your LLM supports 512 tokens, and your chunk size is 400 tokens, and you use 3 retrievers, does the LLM receive all 3 at once
### (1200 tokens)? Or one at a time?

### ✅ Answer:
### All 3 chunks are typically passed together in a single prompt — as part of the {context} in your system prompt — unless you 
### manually loop over them or limit the context size.

###🧠 Here's what's happening under the hood:
###    1.Retriever returns the top k relevant documents (in your case, 3 chunks, each 400 tokens).
###    2.These 3 documents are concatenated into one string and inserted into {context} in your prompt.
###    3.Your prompt becomes something like:
###       "You are an assistant... only use the context below...
###       Context:
###       [chunk 1, ~400 tokens]
###       [chunk 2, ~400 tokens]
###       [chunk 3, ~400 tokens]
###       User: What is XYZ?"

###    4.Total token count:
###    System + Prompt Template ≈ ~50 tokens
###    Context: 3 × 400 = 1200 tokens
###    Question: ~10–30 tokens
###    → Total: ~1300 tokens, which exceeds your LLM limit (512 tokens).

### ⚠️ What happens when you exceed the token limit?
###     If you're using a strict model like Flan-T5, it will truncate or fail.
###     You might see incomplete answers or errors.
###     Your LLM may only process the last part of the context (e.g., chunk 3 only), which leads to irrelevant or short answers.

### ✅ Solutions:
###    Reduce chunk size
###    → Try chunk_size=150 and chunk_overlap=30. Then 3 chunks = ~450 tokens.
###    Reduce number of retrieved documents
###    → Use retriever = vectorstore.as_retriever(k=1 or 2).
###    Summarize or rank chunks before passing to LLM
###    → (Advanced) Run a pre-step that merges or filters chunks into fewer tokens.
###    Switch to an LLM with larger context window
###    → Use a model like Mistral 7B (context ~8k tokens) if resources allow.

# %%
### The dimension of an embedding model — like 384, 768, 1024, etc. — plays a key role in how text is represented numerically. Let’s
### break down what happens when you use a low vs. high dimensional embedding model, especially in a chatbot or vector search setting
### (like Pinecone + LLM).

### 🔢 What Is Embedding Dimension?
### The embedding dimension is the size of the numeric vector that represents a piece of text (sentence, paragraph, etc.).
### For example:
###    all-MiniLM-L6-v2 → 384-dimensional
###    all-mpnet-base-v2 → 768-dimensional
###    BAAI/bge-large-en → 1024-dimensional

### 📉 Low-Dimensional Embeddings (e.g., 384)
###    ✅ Pros:
###       Smaller storage: Each vector is lighter (good for Pinecone costs).
###       Faster computation: Quicker similarity searches, distance calculations.
###       Lower memory usage: Useful for low-resource environments.
###    ❌ Cons:
###       Lower expressiveness: Might miss nuances in meaning.
###       More overlap between vectors: Especially in large datasets, different meanings might seem “close”.

### 📈 High-Dimensional Embeddings (e.g., 768–1024+)
###   ✅ Pros:
###    More expressive: Captures richer semantics, word context, syntax.
###    Better accuracy: Especially for dense documents or longer context.
###    Less collision: Similar-looking sentences are less likely to be misinterpreted.
###  ❌ Cons:
###    Slower & heavier: More memory, compute, and bandwidth.
###    Costly in vector DBs: Indexing and querying is more expensive (e.g., in Pinecone).
###    May overfit: On small datasets, large dimensions can lead to noisy similarity scores.

### ⚖️ Conclusion
###    Low-dimensional (384) → ✅ Good for quick, simple, low-resource tasks.
###    High-dimensional (768–1024) → ✅ Better for precision, dense queries, technical content (like your medical chatbot).

### 👉 But always match Pinecone’s index dimension to the model’s output. If the dimensions mismatch, you’ll get an error or misleading 
### results.

# %%
### chunk overlap plays a very important role in improving the context awareness and answer accuracy of your LLM-based chatbot, 
### especially when using retrieval-based systems (RAG) like yours.

### 🧩 What is chunk overlap?
### When splitting a long document into smaller chunks (e.g., 400 tokens each), chunk overlap means repeating a portion of the previous chunk in the next one.
### Example:
###    Chunk size = 400 tokens
###    Overlap = 50 tokens
### So, the chunks look like:
###    Chunk 1: tokens 0–399
###    Chunk 2: tokens 350–749 ← overlaps 50 tokens from chunk 1
###    Chunk 3: tokens 700–1099 ← overlaps 50 tokens from chunk 2

### ✅ Why is chunk overlap important?
###    1. Preserves context across boundaries
###        Sometimes, important information (definitions, names, conclusions) falls between two chunks. Without overlap, that 
###        information might get split and lost in both chunks.

###    2. Improves search recall (retrieval quality)
###         When embedding chunks for vector search (Pinecone), overlapping helps capture more meaningful embeddings — especially when:
###         Sentences are long
###         Sections span multiple paragraphs
###       This makes similarity search more accurate.

###    3.Reduces hallucinations in LLM answers
###     Because the retriever returns complete, overlapping context, the LLM can answer based on fully intact facts, not partial or 
###     clipped information.

### ⚠️ What if you don’t use chunk overlap?
###    You risk cutting off important sentences, especially around the boundaries.
###    Retrieval might miss critical context.
###    Answers may feel short, incomplete, or even incorrect.

# %%
### response time in your chatbot depends on several parts of the RAG pipeline, so you can reduce latency by optimizing both 
### your retrieval and your LLM inference.

### 1️⃣ Speed Up Retrieval from Pinecone
###     Reduce Retriever k
###   *     You’re currently using k=3 (3 document chunks). If your LLM can work well with less, try k=2 to reduce retrieval and prompt length.
###     Optimize Embedding Search
###         Make sure your Pinecone index metric matches your embedding type (cosine, dot product, or Euclidean).
###         Use smaller dimension embeddings (e.g., 384 instead of 768) if accuracy remains good — smaller vectors = faster search.
###   * Warm Up the Connection
###         Call the retriever once at startup with a dummy query to keep the Pinecone connection alive. This avoids first-query delays.

### 2️⃣ Optimize the LLM Inference
###     Choose a Faster Model
###         google/flan-t5-base is ~250M params — not huge, but you could try flan-t5-small (fewer parameters, faster) or other small instruction-tuned models.
###         Or use quantized models from Hugging Face (e.g., 8-bit or 4-bit weights).
###   * Lower max_new_tokens
###         If your responses don’t need to be long, set max_new_tokens=100 or lower to reduce generation time.
###     Load Model Locally
###        Avoid downloading from Hugging Face on every run — save locally and load from disk.

### 3️⃣ Preprocessing and Chunking Improvements
###     Reduce Chunk Size
###         Smaller chunks (e.g., 256 tokens instead of 400) mean faster LLM processing — but keep enough context for answers.
###     Smarter Prompt Templates
###        Keep your system prompt short but clear — large system prompts eat into token budget and slow down inference.

### 4️⃣ Parallel or Cached Operations
###     Use Retrieval Cache
###         Cache embeddings and retrieval results for repeated queries.
###     Parallelize Requests
###        If you have multiple user queries, send them in batches instead of sequentially.

# %%
                                           ############################### Python 3.10.0 ################################



################## requred dor app ###############3
#python-dotenv==1.1.1    
### from dotenv import load_dotenv (load the environment variables in .env file)

#langchain==0.3.27        
### from langchain.prompts import PromptTemplate   (to create LLM system prompt) 
### from langchain.chains.combine_documents import create_stuff_documents_chain (combining retriever, user question, and instructions and pass to the LLM)
### from langchain.chains import create_retrieval_chain  (to connct the LLM with pinecone vector DB)
### from langchain.text_splitter import RecursiveCharacterTextSplitter ( to chunk extracted data) 

#transformers==4.55.0     
### from transformers import pipeline  (download a LLM from hugginhface and load it locally)

#pinecone-client==6.0.0  
### from langchain_pinecone import PineconeVectorStore (to embedding chunked data and upload to pinecone simultaniousy. Moreover to import exsisting index frompinecone)
### from pinecone import Pinecone (to create a connection with pinecone)
### from pinecone import ServerlessSpec ( to creat a index)

#langchain-huggingface==0.3.1 
### from langchain_huggingface import HuggingFaceEmbeddings  (to load the embedding model from locally which downloaded by huggingface) 
### from langchain_huggingface import HuggingFacePipeline   ( to convert huggingface model into langchain-compatible object)

#langchain-pinecone==0.2.11    
### langchain_pinecone

#sentence-transformers==5.1.0
### from sentence_transformers import SentenceTransformer (to download a embedding model from huggingface)  
### HuggingFaceEmbeddings    ( for embedding sentences, chunks)

#streamlit==1.48.0
### Model deploy



##### requred only .ipynb file ##################
#huggingface-hub==0.34.3
### For login to hugginhface account

#ipykernel==6.30.1
### To add kernel for jupiternote book files

#langchain-community==0.3.27
#pypdf==5.9.0
### from langchain.document_loaders import PyPDFLoader  ( pdf load and extract)

#ipywidgets==8.1.7
### to work with jupiter notebook file
